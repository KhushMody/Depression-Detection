# %%
#imports
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import Perceptron
from sklearn.metrics import precision_recall_fscore_support
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
from sklearn.metrics.pairwise import cosine_similarity
import torch
from torch.utils.data import DataLoader, Dataset
import torch.nn as nn
import torch.nn.functional as F
import functools
from sklearn.metrics import accuracy_score 
import gensim

# %%
# !pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 14.8 MB/s eta 0:00:00
# Collecting pyahocorasick
#   Downloading pyahocorasick-2.0.0-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 15.3 MB/s eta 0:00:00
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.2 contractions-0.1.73 pyahocorasick-2.0.0 textsearch-0.0.24

# %% [markdown]
# READING THE DATA

# %%
import pandas as pd

df = pd.read_csv("depression_dataset_reddit_cleaned.csv",header=0, sep=',',warn_bad_lines=False, error_bad_lines=False)
df_test = pd.read_csv('/content/merged_dataset.csv')
df_test = df_test.drop(['Unnamed: 0'], axis=1)
df_test.head()
# Out:
# <ipython-input-3-15018a8d7b55>:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("depression_dataset_reddit_cleaned.csv",header=0, sep=',',warn_bad_lines=False, error_bad_lines=False)
# <ipython-input-3-15018a8d7b55>:3: FutureWarning: The warn_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("depression_dataset_reddit_cleaned.csv",header=0, sep=',',warn_bad_lines=False, error_bad_lines=False)
#                                              content
# 0                      Don’t worry, it’s just a prop
# 1   It never should have happened but that’s exac...
# 2  Like really, it’s the depressed kids you’re go...
# 3  Hey there, if you're feeling a bit lost and ov...
# 4    no. they are meant to spur demand after elon...

# %%
df
# Out:
#                                              clean_text  is_depression
# 0     we understand that most people who reply immed...              1
# 1     welcome to r depression s check in post a plac...              1
# 2     anyone else instead of sleeping more when depr...              1
# 3     i ve kind of stuffed around a lot in my life d...              1
# 4     sleep is my greatest and most comforting escap...              1
# ...                                                 ...            ...
# 7726                                       is that snow              0
# 7727                 moulin rouge mad me cry once again              0
# 7728  trying to shout but can t find people on the list              0
# 7729  ughh can t find my red sox hat got ta wear thi...              0
# 7730  slept wonderfully finally tried swatching for ...              0
#
# [7731 rows x 2 columns]

# %% [markdown]
# DATA CLEANING AND PREPROCESSING

# %%
df['clean_text'] = df['clean_text'].str.replace(r'<[^<>]*>', '', regex=True)#1
df['clean_text'] = df['clean_text'].str.replace(r'http://\S+|https://\S+', '', regex=True)#2
df['clean_text']=df['clean_text'].str.lower()
df['clean_text'] = df['clean_text'].str.replace(r'[@_!#$%^&*()<>?/\|}{~:]', '', regex=True)#5
df['clean_text'] = df['clean_text'].replace("\s+", " ", regex=True).str.strip()#last
after_dc=df['clean_text'].str.len().mean()
df_test['clean_text'] = df_test['content'].str.replace(r'<[^<>]*>', '', regex=True)#1
df_test['clean_text'] = df_test['clean_text'].str.replace(r'http://\S+|https://\S+', '', regex=True)#2
df_test['clean_text']=df_test['clean_text'].str.lower()
df_test['clean_text'] = df_test['clean_text'].str.replace(r'[@_!#$%^&*()<>?/\|}{~:]', '', regex=True)#5
df_test['clean_text'] = df_test['clean_text'].replace("\s+", " ", regex=True).str.strip()#last
#after_dc=df['clean_text'].str.len().mean()

#DATA PREPOCESSING
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger') 
nltk.download('wordnet')
nltk.download('omw-1.4')

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
lemmatizer = nltk.stem.WordNetLemmatizer()
wordnet_lemmatizer = WordNetLemmatizer()
stop = stopwords.words('english')


def nltk_tag_to_wordnet_tag(nltk_tag):
    if nltk_tag.startswith('J'):
        return wordnet.ADJ
    elif nltk_tag.startswith('V'):
        return wordnet.VERB
    elif nltk_tag.startswith('N'):
        return wordnet.NOUN
    elif nltk_tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def lemmatize_sentence(sentence):
    #tokenize the sentence and find the POS tag for each token
    nltk_tagged = nltk.pos_tag(nltk.word_tokenize(sentence))
    #tuple of (token, wordnet_tag)
    wordnet_tagged = map(lambda x: (x[0], nltk_tag_to_wordnet_tag(x[1])), nltk_tagged)
    lemmatized_sentence = []
    for word, tag in wordnet_tagged:
        if tag is None:
            #if there is no available tag, append the token as is
            lemmatized_sentence.append(word)
        else:
            #else use the tag to lemmatize the token
            lemmatized_sentence.append(lemmatizer.lemmatize(word, tag))
    return " ".join(lemmatized_sentence)



# Lemmatizing
df['clean_text'] = df['clean_text'].apply(lambda x: lemmatize_sentence(x))
df_test['clean_text'] = df_test['clean_text'].apply(lambda x: lemmatize_sentence(x))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...

# %%
df_test = df_test.drop(['content'], axis = 1)
df_test.head()
# Out:
#                                           clean_text
# 0                 don ’ t worry , it ’ s just a prop
# 1  it never should have happen but that ’ s exact...
# 2  like really , it ’ s the depressed kid you ’ r...
# 3  hey there , if you 're feel a bit lose and ove...
# 4  no . they be mean to spur demand after elon bo...

# %% [markdown]
# WORD2VEC MODEL

# %%
#The pretrained googleW2V model is loaded to generate the word embeddings
import gensim.downloader as googleW2V
google_w2v = googleW2V.load("word2vec-google-news-300")
# Out:
# [=================================================-] 99.8% 1659.5/1662.8MB downloaded

# %% [markdown]
# SPLITTING DATA INTO TRAIN AND TEST

# %%
X=df['clean_text']
y=df['is_depression']

X_unlabeled = df_test['clean_text']
X_unlabeled.head()
# Out:
# 0                   don ’ t worry , it ’ s just a prop
# 1    it never should have happen but that ’ s exact...
# 2    like really , it ’ s the depressed kid you ’ r...
# 3    hey there , if you 're feel a bit lose and ove...
# 4    no . they be mean to spur demand after elon bo...
# Name: clean_text, dtype: object

# %%
#dataset is split into training and testing sets and the indexes are reset 
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

# %%
X_train = X_train.reset_index(drop=True)

# %%
X_test = X_test.reset_index(drop=True)

# %%
y_train = y_train.reset_index(drop=True)

# %%
y_test = y_test.reset_index(drop=True)

# %% [markdown]
# AVERAGE OF THE VECTORS

# %%
#The average is found between all the vectors corresponding to the words in a sentence.
#Average found and appended for each sentence for the training set
X_train1 = []
X_unlabeled1 = []

for x in X_train:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = google_w2v[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_train1.append(np.mean(wordveclist, axis=0))

for x in X_unlabeled:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = google_w2v[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_unlabeled1.append(np.mean(wordveclist, axis=0))
# Out:
# /usr/local/lib/python3.9/dist-packages/numpy/core/fromnumeric.py:3474: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.9/dist-packages/numpy/core/_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
#Average found and appended for each sentence for the test set
X_test1 = []
for x in X_test:
    wordveclist = []
    for word in x.split(' '):
        try:
            wordvec = google_w2v[word]
            wordveclist.append(wordvec)
        except:
            pass
    X_test1.append(np.mean(wordveclist, axis=0))

# %%
X_unlabeled1[:5]
# Out:
# [array([-2.40652896e-02,  7.53672495e-02, -8.52399543e-02,  1.20186940e-01,
#         -9.16748047e-02,  1.88337057e-03,  2.46276855e-02, -6.94754496e-02,
#          1.25313893e-01, -7.44628906e-03, -5.99670410e-03, -1.12409316e-01,
#         -6.56999871e-02,  2.71944311e-02, -1.67445585e-01,  1.47251680e-01,
#          9.30960551e-02,  1.55587330e-01, -4.85316701e-02, -1.27790183e-01,
#         -9.62960348e-02,  3.05873323e-02,  1.12670898e-01, -1.95922852e-02,
#          8.67396742e-02,  4.01349738e-02, -7.62416273e-02, -4.43551205e-02,
#          2.16500424e-02, -4.72935252e-02, -1.13568986e-02,  1.09165736e-01,
#          4.40757759e-02, -1.26106264e-02,  1.67160039e-03,  7.74726868e-02,
#          4.50897205e-04, -1.17492676e-03, -6.85501099e-02, -3.19103226e-02,
#          2.58888248e-02,  2.29614265e-02, -4.82833870e-02,  6.15737922e-02,
#         -6.28875718e-02,  1.82895660e-02, -2.62901299e-02, -4.15069573e-02,
#         -1.18621830e-02, -5.05264290e-02,  4.97327819e-02, -9.73472558e-03],
#        dtype=float32)]

# %%
#non word vector values are removed 
wv_train = []
for i, x in enumerate(X_train1):
    try:
        len(x)
        wv_train.append(i)
    except:
        print(i)
        print(x)
        
wv_unlabeled = []
for i, x in enumerate(X_unlabeled1):
    try:
        len(x)
        wv_unlabeled.append(i)
    except:
        print(i)
        print(x)


wv_test = []
for i, x in enumerate(X_test1):
    try:
        len(x)
        wv_test.append(i)
    except:
        print(x)
X_train1 = [X_train1[i] for i in wv_train]
X_test1 = [X_test1[i] for i in wv_test]
X_unlabeled1 = [X_unlabeled1[i] for i in wv_unlabeled]
y_train1 = [y_train[i] for i in wv_train]
y_test1 = [y_test[i] for i in wv_test]
# Out:
# 2088
# nan
# 2420
# nan
# 2961
# nan
# 3536
# nan
# 3798
# nan
# 4738
# nan
# 4739
# nan
# 4985
# nan
# 5114
# nan
# 5123
# nan
# 5511
# nan
# 5513
# nan
# 5972
# nan
# 32
# nan
# 3142
# nan
# 3163
# nan
# 3584
# nan
# 3832
# nan
# 5356
# nan
# 6481
# nan
# 8596
# nan
# 8639
# nan
# 9802
# nan
# 9907
# nan
# 11492
# nan
# 11502
# nan
# 11876
# nan
# 12570
# nan
# 13443
# nan
# 13644
# nan
# 14035
# nan
# 14200
# nan
# 14769
# nan
# 15572
# nan
# 16747
# nan
# 18189
# nan
# 18430
# nan
# 18431
# nan
# 18913
# nan
# 18920
# nan
# 18922
# nan
# 18929
# nan
# 18940
# nan
# 18976
# nan
# 19018
# nan
# 19020
# nan
# 19096
# nan
# 19120
# nan
# 19194
# nan
# 19209
# nan
# 19288
# nan
# 19387
# nan
# 19526
# nan
# 19534
# nan
# 19539
# nan
# 19573
# nan
# 19633
# nan
# 19642
# nan
# 19657
# nan
# 19671
# nan
# 19714
# nan
# 19756
# nan
# 19806
# nan
# 19811
# nan
# 20234
# nan
# 20330
# nan
# 20426
# nan
# 20486
# nan
# 20568
# nan
# 20738
# nan
# 20981
# nan
# 21317
# nan
# 21681
# nan
# 21777
# nan
# nan
# nan

# %% [markdown]
# TF-IDF VECTORIZATION

# %% [markdown]
# PERCEPTRON

# %% [markdown]
# NEURAL NETS

# %%
# !pip install torch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: torch in /usr/local/lib/python3.9/dist-packages (2.0.0+cu118)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch) (3.11.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch) (16.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch) (1.3.0)

# %%
#imports
import torch
from torch.utils.data import DataLoader, Dataset
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Enable CUDA
use_cuda = torch.cuda.is_available()
device = torch.device("cuda:0" if use_cuda else "cpu")
torch.backends.cudnn.benchmark = True

# %%
class Dataset:
    
    def __init__(self, X, y):
        self.X=torch.as_tensor(X)
        self.y=torch.as_tensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, index):
        X_1=self.X[index]
        y_1=self.y[index]
        return X_1, y_1

# %%
#Training dataset split into training and validation set so we have a division of 60(training), 20(validation) and 20(testing)
from sklearn.model_selection import train_test_split

X_train_f, X_val_f, y_train_f, y_val_f = train_test_split(
    X_train1, y_train1, test_size=0.2, random_state=0)

# %%
#genearting the training set, testing set and the validation set
train_set = Dataset(X_train_f, y_train_f)
valid_set = Dataset(X_val_f, y_val_f)
test_set = Dataset(X_test1, y_test1)
unlabeled_set = Dataset(X_unlabeled1, np.zeros(len(X_unlabeled1)))
#Generating the data loaders for the training set, testing set and the validation set
#train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(valid_set,  batch_size=32, shuffle=True, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_set, shuffle=False)
#unlabeled_loader = torch.utils.data.DataLoader(unlabeled_set, shuffle=False)
# Out:
# <ipython-input-21-deb5d617ec55>:4: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at ../torch/csrc/utils/tensor_new.cpp:245.)
#   self.X=torch.as_tensor(X)

# %%
# for x,y in unlabeled_loader:
#   print(x,y)
#   print(len(x))
#   break

# %%
#Generating the network architechture
class Net(nn.Module):
    def __init__(self, input_dim=300, output_dim=1, hidden_1=100, hidden_2=10):
        super(Net, self).__init__()
        self.input_dim = input_dim 
        self.output_dim = output_dim
        self.hidden_1 = hidden_1
        self.hidden_2 = hidden_2
        self.fc1 = nn.Linear(self.input_dim, self.hidden_1)
        self.fc2 = nn.Linear(self.hidden_1, self.hidden_2)
        self.fc3 = nn.Linear(self.hidden_2, self.output_dim)
        self.dropout = nn.Dropout(0.2)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc3(x))
        return x

# %%
#Calling the Net is_depression to initialize the neural network
model_te = Net()
print(model_te)
# Out:
# Net(
#   (fc1): Linear(in_features=300, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
#Defining the loss and the optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model_te.parameters(), lr=0.01)

# %%
#traning and validating the model
valid_loss_min = np.Inf
max_epochs=45
flag = 0
while(flag == 0):
  train_set = Dataset(X_train_f, y_train_f)
  train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=0)
  unlabeled_set = Dataset(X_unlabeled1, np.zeros(len(X_unlabeled1)))
  unlabeled_loader = torch.utils.data.DataLoader(unlabeled_set, shuffle=False)
  for epoch in range(max_epochs):
      train_loss = 0.0
      valid_loss = 0.0
      model_te.train()
      for data, target in train_loader:
          optimizer.zero_grad()
          output = model_te(data)

          #print(output)
          #print(target)
          target = target.unsqueeze(1)
          target = target.float()
          loss = criterion(output, target)
          loss.backward()
          optimizer.step()
          train_loss += loss.item()*data.size(0)
      model_te.eval()
      for data, target in valid_loader:
          output = model_te(data)
          target = target.unsqueeze(1)
          target = target.float()
          loss = criterion(output, target)
          valid_loss += loss.item()*data.size(0)
      train_loss = train_loss/len(train_loader.dataset)
      valid_loss = valid_loss/len(valid_loader.dataset)
      #Printing the loss values
      print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
          epoch+1, 
          train_loss,
          valid_loss
          ))
      if valid_loss <= valid_loss_min:
          print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
          valid_loss_min,
          valid_loss))
          torch.save(model_te.state_dict(), 'model_te.pt')
          valid_loss_min = valid_loss
  
  flag = 1
  model_te.load_state_dict(torch.load('model_te.pt'))
  k=0
  products_list = ['laptop', 'printer', 'tablet', 'desk', 'chair']

  df_unlabeled = pd.DataFrame(zip(X_unlabeled1), columns = ['text'])
  drp = []
  print(len(X_train_f),len(y_train_f), len(X_unlabeled1))
  for i ,batch in enumerate(unlabeled_loader):
    outputs = model_te(batch[0][0])
    #print(len(batch[0][0]))
    #print(outputs)
    if(outputs[0]<= 0.1 or outputs[0] > 0.9):
      flag = 0
      X_train_f.append(batch[0][0])
      if(outputs[0] < 0.5):
        y_train_f.append(0)
      else:
        y_train_f.append(1)
      drp.append(i)
    
        #X_train_f.append(batch)
  
    #print(outputs[1])
    #break
  df_unlabeled = df_unlabeled.drop(drp)
  X_unlabeled1 = df_unlabeled['text'].values.tolist()
  print(len(X_train_f),len(y_train_f), len(X_unlabeled1))
  #print(X_unlabeled1[0])
  #print(type(X_unlabeled1[0]))
  #print(type(X_unlabeled1))
# Out:
# Epoch: 1 	Training Loss: 0.697272 	Validation Loss: 0.694007
# Validation loss decreased (inf --> 0.694007).  Saving model ...
# Epoch: 2 	Training Loss: 0.694688 	Validation Loss: 0.692967
# Validation loss decreased (0.694007 --> 0.692967).  Saving model ...
# Epoch: 3 	Training Loss: 0.693644 	Validation Loss: 0.692607
# Validation loss decreased (0.692967 --> 0.692607).  Saving model ...
# Epoch: 4 	Training Loss: 0.693180 	Validation Loss: 0.692383
# Validation loss decreased (0.692607 --> 0.692383).  Saving model ...
# Epoch: 5 	Training Loss: 0.692668 	Validation Loss: 0.692237
# Validation loss decreased (0.692383 --> 0.692237).  Saving model ...
# Epoch: 6 	Training Loss: 0.692515 	Validation Loss: 0.692108
# Validation loss decreased (0.692237 --> 0.692108).  Saving model ...
# Epoch: 7 	Training Loss: 0.692138 	Validation Loss: 0.691913
# Validation loss decreased (0.692108 --> 0.691913).  Saving model ...
# Epoch: 8 	Training Loss: 0.692103 	Validation Loss: 0.691691
# Validation loss decreased (0.691913 --> 0.691691).  Saving model ...
# Epoch: 9 	Training Loss: 0.691971 	Validation Loss: 0.691509
# Validation loss decreased (0.691691 --> 0.691509).  Saving model ...
# Epoch: 10 	Training Loss: 0.692062 	Validation Loss: 0.691284
# Validation loss decreased (0.691509 --> 0.691284).  Saving model ...
# Epoch: 11 	Training Loss: 0.691561 	Validation Loss: 0.691049
# Validation loss decreased (0.691284 --> 0.691049).  Saving model ...
# Epoch: 12 	Training Loss: 0.691215 	Validation Loss: 0.690804
# Validation loss decreased (0.691049 --> 0.690804).  Saving model ...
# Epoch: 13 	Training Loss: 0.690905 	Validation Loss: 0.690572
# Validation loss decreased (0.690804 --> 0.690572).  Saving model ...
# Epoch: 14 	Training Loss: 0.690967 	Validation Loss: 0.690274
# Validation loss decreased (0.690572 --> 0.690274).  Saving model ...
# Epoch: 15 	Training Loss: 0.690468 	Validation Loss: 0.689978
# Validation loss decreased (0.690274 --> 0.689978).  Saving model ...
# Epoch: 16 	Training Loss: 0.690022 	Validation Loss: 0.689597
# Validation loss decreased (0.689978 --> 0.689597).  Saving model ...
# Epoch: 17 	Training Loss: 0.689905 	Validation Loss: 0.689244
# Validation loss decreased (0.689597 --> 0.689244).  Saving model ...
# Epoch: 18 	Training Loss: 0.689794 	Validation Loss: 0.688788
# Validation loss decreased (0.689244 --> 0.688788).  Saving model ...
# Epoch: 19 	Training Loss: 0.688981 	Validation Loss: 0.688361
# Validation loss decreased (0.688788 --> 0.688361).  Saving model ...
# Epoch: 20 	Training Loss: 0.688188 	Validation Loss: 0.687817
# Validation loss decreased (0.688361 --> 0.687817).  Saving model ...
# Epoch: 21 	Training Loss: 0.688056 	Validation Loss: 0.687260
# Validation loss decreased (0.687817 --> 0.687260).  Saving model ...
# Epoch: 22 	Training Loss: 0.687132 	Validation Loss: 0.686615
# Validation loss decreased (0.687260 --> 0.686615).  Saving model ...
# Epoch: 23 	Training Loss: 0.686855 	Validation Loss: 0.685867
# Validation loss decreased (0.686615 --> 0.685867).  Saving model ...
# Epoch: 24 	Training Loss: 0.685431 	Validation Loss: 0.684969
# Validation loss decreased (0.685867 --> 0.684969).  Saving model ...
# Epoch: 25 	Training Loss: 0.685622 	Validation Loss: 0.684051
# Validation loss decreased (0.684969 --> 0.684051).  Saving model ...
# Epoch: 26 	Training Loss: 0.683979 	Validation Loss: 0.682966
# Validation loss decreased (0.684051 --> 0.682966).  Saving model ...
# Epoch: 27 	Training Loss: 0.682748 	Validation Loss: 0.681801
# Validation loss decreased (0.682966 --> 0.681801).  Saving model ...
# Epoch: 28 	Training Loss: 0.681705 	Validation Loss: 0.680335
# Validation loss decreased (0.681801 --> 0.680335).  Saving model ...
# Epoch: 29 	Training Loss: 0.680351 	Validation Loss: 0.678720
# Validation loss decreased (0.680335 --> 0.678720).  Saving model ...
# Epoch: 30 	Training Loss: 0.678897 	Validation Loss: 0.676797
# Validation loss decreased (0.678720 --> 0.676797).  Saving model ...
# Epoch: 31 	Training Loss: 0.677205 	Validation Loss: 0.674525
# Validation loss decreased (0.676797 --> 0.674525).  Saving model ...
# Epoch: 32 	Training Loss: 0.674142 	Validation Loss: 0.671705
# Validation loss decreased (0.674525 --> 0.671705).  Saving model ...
# Epoch: 33 	Training Loss: 0.671234 	Validation Loss: 0.668437
# Validation loss decreased (0.671705 --> 0.668437).  Saving model ...
# Epoch: 34 	Training Loss: 0.667906 	Validation Loss: 0.664600
# Validation loss decreased (0.668437 --> 0.664600).  Saving model ...
# Epoch: 35 	Training Loss: 0.663965 	Validation Loss: 0.660179
# Validation loss decreased (0.664600 --> 0.660179).  Saving model ...
# Epoch: 36 	Training Loss: 0.660142 	Validation Loss: 0.655038
# Validation loss decreased (0.660179 --> 0.655038).  Saving model ...
# Epoch: 37 	Training Loss: 0.656096 	Validation Loss: 0.649231
# Validation loss decreased (0.655038 --> 0.649231).  Saving model ...
# Epoch: 38 	Training Loss: 0.647685 	Validation Loss: 0.641952
# Validation loss decreased (0.649231 --> 0.641952).  Saving model ...
# Epoch: 39 	Training Loss: 0.638627 	Validation Loss: 0.632837
# Validation loss decreased (0.641952 --> 0.632837).  Saving model ...
# Epoch: 40 	Training Loss: 0.631797 	Validation Loss: 0.623627
# Validation loss decreased (0.632837 --> 0.623627).  Saving model ...
# Epoch: 41 	Training Loss: 0.618936 	Validation Loss: 0.610604
# Validation loss decreased (0.623627 --> 0.610604).  Saving model ...
# Epoch: 42 	Training Loss: 0.608005 	Validation Loss: 0.596940
# Validation loss decreased (0.610604 --> 0.596940).  Saving model ...
# Epoch: 43 	Training Loss: 0.594769 	Validation Loss: 0.581996
# Validation loss decreased (0.596940 --> 0.581996).  Saving model ...
# Epoch: 44 	Training Loss: 0.578280 	Validation Loss: 0.564717
# Validation loss decreased (0.581996 --> 0.564717).  Saving model ...
# Epoch: 45 	Training Loss: 0.559586 	Validation Loss: 0.545641
# Validation loss decreased (0.564717 --> 0.545641).  Saving model ...
# 4936 4936 21745
# 4951 4951 21730
# Epoch: 1 	Training Loss: 0.544178 	Validation Loss: 0.526217
# Validation loss decreased (0.545641 --> 0.526217).  Saving model ...
# Epoch: 2 	Training Loss: 0.523814 	Validation Loss: 0.506109
# Validation loss decreased (0.526217 --> 0.506109).  Saving model ...
# Epoch: 3 	Training Loss: 0.504591 	Validation Loss: 0.485773
# Validation loss decreased (0.506109 --> 0.485773).  Saving model ...
# Epoch: 4 	Training Loss: 0.490369 	Validation Loss: 0.468322
# Validation loss decreased (0.485773 --> 0.468322).  Saving model ...
# Epoch: 5 	Training Loss: 0.468277 	Validation Loss: 0.447806
# Validation loss decreased (0.468322 --> 0.447806).  Saving model ...
# Epoch: 6 	Training Loss: 0.451007 	Validation Loss: 0.430101
# Validation loss decreased (0.447806 --> 0.430101).  Saving model ...
# Epoch: 7 	Training Loss: 0.437145 	Validation Loss: 0.418397
# Validation loss decreased (0.430101 --> 0.418397).  Saving model ...
# Epoch: 8 	Training Loss: 0.421611 	Validation Loss: 0.405578
# Validation loss decreased (0.418397 --> 0.405578).  Saving model ...
# Epoch: 9 	Training Loss: 0.407855 	Validation Loss: 0.386023
# Validation loss decreased (0.405578 --> 0.386023).  Saving model ...
# Epoch: 10 	Training Loss: 0.395856 	Validation Loss: 0.374483
# Validation loss decreased (0.386023 --> 0.374483).  Saving model ...
# Epoch: 11 	Training Loss: 0.384787 	Validation Loss: 0.363157
# Validation loss decreased (0.374483 --> 0.363157).  Saving model ...
# Epoch: 12 	Training Loss: 0.372059 	Validation Loss: 0.353591
# Validation loss decreased (0.363157 --> 0.353591).  Saving model ...
# Epoch: 13 	Training Loss: 0.362068 	Validation Loss: 0.344551
# Validation loss decreased (0.353591 --> 0.344551).  Saving model ...
# Epoch: 14 	Training Loss: 0.354655 	Validation Loss: 0.337075
# Validation loss decreased (0.344551 --> 0.337075).  Saving model ...
# Epoch: 15 	Training Loss: 0.348030 	Validation Loss: 0.330049
# Validation loss decreased (0.337075 --> 0.330049).  Saving model ...
# Epoch: 16 	Training Loss: 0.342320 	Validation Loss: 0.325132
# Validation loss decreased (0.330049 --> 0.325132).  Saving model ...
# Epoch: 17 	Training Loss: 0.335572 	Validation Loss: 0.317977
# Validation loss decreased (0.325132 --> 0.317977).  Saving model ...
# Epoch: 18 	Training Loss: 0.330836 	Validation Loss: 0.317279
# Validation loss decreased (0.317977 --> 0.317279).  Saving model ...
# Epoch: 19 	Training Loss: 0.323359 	Validation Loss: 0.308701
# Validation loss decreased (0.317279 --> 0.308701).  Saving model ...
# Epoch: 20 	Training Loss: 0.318046 	Validation Loss: 0.304031
# Validation loss decreased (0.308701 --> 0.304031).  Saving model ...
# Epoch: 39 	Training Loss: 0.052127 	Validation Loss: 0.306722
# Epoch: 40 	Training Loss: 0.047481 	Validation Loss: 0.296818
# Epoch: 41 	Training Loss: 0.046149 	Validation Loss: 0.305134
# Epoch: 42 	Training Loss: 0.045578 	Validation Loss: 0.299843
# Epoch: 43 	Training Loss: 0.047798 	Validation Loss: 0.303177
# Epoch: 44 	Training Loss: 0.045966 	Validation Loss: 0.302892
# Epoch: 45 	Training Loss: 0.047279 	Validation Loss: 0.300271
# 20347 20347 6334
# 20347 20347 6334

# %%
type(X_unlabeled1[0])
# Out:
# numpy.ndarray

# %%
#Function to test the model
def predict(model, dataloader):
    prediction_list = []
    truth_list = []
    m = 0
    cnt = 0
    for i, batch in enumerate(dataloader):
        outputs = model(batch[0])
        if(outputs[0] < 0.5):
          predicted = 0
        else:
          predicted = 1
        #print(batch[1], predicted)
        if(int(batch[1].item()) == int(predicted)):
          m+=1
        cnt+=1
        #_, predicted = torch.max(outputs.data, 1)
        prediction_list.append(int(predicted))
        truth_list.append(int(batch[1].item()))
    #acc = m/cnt
    return prediction_list, truth_list

# %%
from sklearn.metrics import classification_report

#Loading the model and generating the predictions
model_te.load_state_dict(torch.load('model_te.pt'))
pred, true_val = predict(model_te, test_loader)
print(classification_report(true_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       778
#            1       0.91      0.93      0.92       767
#
#     accuracy                           0.92      1545
#    macro avg       0.92      0.92      0.92      1545
# weighted avg       0.92      0.92      0.92      1545

# %% [markdown]
# # BERT

# %%
# !pip install -U sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 77.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (0.15.1+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.8 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.4.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.11.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 114.2 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=3a67d550be7a27d6f3eb6631e37430b2cdf1c921a706168eaf5c9f8e30f56d17
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.14.1 sentence-transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1

# %%
from sentence_transformers import SentenceTransformer
model_bert = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
X=df['clean_text']
y=df['is_depression']

X_unlabeled = df_test['clean_text']
X_unlabeled.head()
# Out:
# 0                   don ’ t worry , it ’ s just a prop
# 1    it never should have happen but that ’ s exact...
# 2    like really , it ’ s the depressed kid you ’ r...
# 3    hey there , if you 're feel a bit lose and ove...
# 4    no . they be mean to spur demand after elon bo...
# Name: clean_text, dtype: object

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

# %%
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

# %%
X_train1 = []
X_unlabeled1 = []

for x in X_train:
    wordveclist = []
    emb = model_bert.encode(x)
    X_train1.append(emb)

for x in X_unlabeled:
    wordveclist = []
    X_unlabeled1.append(model_bert.encode(x))

# %%
print(len(X_train), len(X_train1))
print(len(X_train1[0]))
# Out:
# 6184 6184
# 384

# %%
X_test1 = []
for x in X_test:
    wordveclist = []
    X_test1.append(model_bert.encode(x))

# %%
class Dataset:
    
    def __init__(self, X, y):
        self.X=torch.as_tensor(X)
        self.y=torch.as_tensor(y)
        
    def __len__(self):
        return len(self.X)
    
    def __getitem__(self, index):
        X_1=self.X[index]
        y_1=self.y[index]
        return X_1, y_1

# %%
y_train_lst = y_train.values.tolist()

# %%
print(y_train_lst[:5])
len(y_train_lst)
# Out:
# [1, 1, 1, 1, 0]
# 6184

# %%
from sklearn.model_selection import train_test_split

#y_train_lst = y_train.values.tolist()
X_train_f, X_val_f, y_train_f, y_val_f = train_test_split(
    X_train1, y_train_lst, test_size=0.2, random_state=0)

# %%
#train_set = Dataset(X_train_f, y_train_f.values)
valid_set = Dataset(X_val_f, y_val_f)
test_set = Dataset(X_test1, y_test.values)
unlabeled_set = Dataset(X_unlabeled1, np.zeros(len(X_unlabeled1)))
#Generating the data loaders for the training set, testing set and the validation set
#train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=0)
#train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=0)
valid_loader = torch.utils.data.DataLoader(valid_set,  batch_size=32, shuffle=True, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_set, shuffle=False)
#unlabeled_loader = torch.utils.data.DataLoader(unlabeled_set, shuffle=False)

# %%
#Generating the network architechture
class Net(nn.Module):
    def __init__(self, input_dim=384, output_dim=1, hidden_1=100, hidden_2=10):
        super(Net, self).__init__()
        self.input_dim = input_dim 
        self.output_dim = output_dim
        self.hidden_1 = hidden_1
        self.hidden_2 = hidden_2
        self.fc1 = nn.Linear(self.input_dim, self.hidden_1)
        self.fc2 = nn.Linear(self.hidden_1, self.hidden_2)
        self.fc3 = nn.Linear(self.hidden_2, self.output_dim)
        self.dropout = nn.Dropout(0.2)
    
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.dropout(x)
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = torch.sigmoid(self.fc3(x))
        return x

# %%
#Calling the Net is_depression to initialize the neural network
model_te = Net()
print(model_te)
# Out:
# Net(
#   (fc1): Linear(in_features=384, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
#   (fc3): Linear(in_features=10, out_features=1, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
#Defining the loss and the optimizer
criterion = nn.BCELoss()
optimizer = torch.optim.SGD(model_te.parameters(), lr=0.01)

# %%
valid_loss_min = np.Inf
max_epochs=45
flag = 0
while(flag == 0):
  train_set = Dataset(X_train_f, y_train_f)
  train_loader = torch.utils.data.DataLoader(train_set, batch_size=32, shuffle=True, num_workers=0)
  unlabeled_set = Dataset(X_unlabeled1, np.zeros(len(X_unlabeled1)))
  unlabeled_loader = torch.utils.data.DataLoader(unlabeled_set, shuffle=False)
  for epoch in range(max_epochs):
      train_loss = 0.0
      valid_loss = 0.0
      model_te.train()
      for data, target in train_loader:
          optimizer.zero_grad()
          output = model_te(data)

          #print(output)
          #print(target)
          target = target.unsqueeze(1)
          target = target.float()
          loss = criterion(output, target)
          loss.backward()
          optimizer.step()
          train_loss += loss.item()*data.size(0)
      model_te.eval()
      for data, target in valid_loader:
          output = model_te(data)
          target = target.unsqueeze(1)
          target = target.float()
          loss = criterion(output, target)
          valid_loss += loss.item()*data.size(0)
      train_loss = train_loss/len(train_loader.dataset)
      valid_loss = valid_loss/len(valid_loader.dataset)
      #Printing the loss values
      print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
          epoch+1, 
          train_loss,
          valid_loss
          ))
      if valid_loss <= valid_loss_min:
          print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
          valid_loss_min,
          valid_loss))
          torch.save(model_te.state_dict(), 'model_te.pt')
          valid_loss_min = valid_loss
  
  flag = 1
  model_te.load_state_dict(torch.load('model_te.pt'))
  k=0

  df_unlabeled = pd.DataFrame(zip(X_unlabeled1), columns = ['text'])
  drp = []
  print(len(X_train_f),len(y_train_f), len(X_unlabeled1))
  for i ,batch in enumerate(unlabeled_loader):
    outputs = model_te(batch[0][0])
    #print(len(batch[0][0]))
    #print(outputs)
    if(outputs[0]<= 0.1 or outputs[0] > 0.9):
      flag = 0
      X_train_f.append(batch[0][0])
      if(outputs[0] < 0.5):
        y_train_f.append(0)
      else:
        y_train_f.append(1)
      drp.append(i)
    
        #X_train_f.append(batch)
  
    #print(outputs[1])
    #break
  df_unlabeled = df_unlabeled.drop(drp)
  X_unlabeled1 = df_unlabeled['text'].values.tolist()
  print(len(X_train_f),len(y_train_f), len(X_unlabeled1))
  #print(X_unlabeled1[0])
  #print(type(X_unlabeled1[0]))
  #print(type(X_unlabeled1))
# Out:
# Epoch: 1 	Training Loss: 0.692810 	Validation Loss: 0.692231
# Validation loss decreased (inf --> 0.692231).  Saving model ...
# Epoch: 2 	Training Loss: 0.692431 	Validation Loss: 0.691946
# Validation loss decreased (0.692231 --> 0.691946).  Saving model ...
# Epoch: 3 	Training Loss: 0.691977 	Validation Loss: 0.691600
# Validation loss decreased (0.691946 --> 0.691600).  Saving model ...
# Epoch: 4 	Training Loss: 0.691603 	Validation Loss: 0.691196
# Validation loss decreased (0.691600 --> 0.691196).  Saving model ...
# Epoch: 5 	Training Loss: 0.691329 	Validation Loss: 0.690720
# Validation loss decreased (0.691196 --> 0.690720).  Saving model ...
# Epoch: 6 	Training Loss: 0.690782 	Validation Loss: 0.690158
# Validation loss decreased (0.690720 --> 0.690158).  Saving model ...
# Epoch: 7 	Training Loss: 0.689999 	Validation Loss: 0.689429
# Validation loss decreased (0.690158 --> 0.689429).  Saving model ...
# Epoch: 8 	Training Loss: 0.689030 	Validation Loss: 0.688502
# Validation loss decreased (0.689429 --> 0.688502).  Saving model ...
# Epoch: 9 	Training Loss: 0.688141 	Validation Loss: 0.687396
# Validation loss decreased (0.688502 --> 0.687396).  Saving model ...
# Epoch: 10 	Training Loss: 0.687098 	Validation Loss: 0.686035
# Validation loss decreased (0.687396 --> 0.686035).  Saving model ...
# Epoch: 11 	Training Loss: 0.685303 	Validation Loss: 0.684189
# Validation loss decreased (0.686035 --> 0.684189).  Saving model ...
# Epoch: 12 	Training Loss: 0.683431 	Validation Loss: 0.681806
# Validation loss decreased (0.684189 --> 0.681806).  Saving model ...
# Epoch: 13 	Training Loss: 0.680308 	Validation Loss: 0.678543
# Validation loss decreased (0.681806 --> 0.678543).  Saving model ...
# Epoch: 14 	Training Loss: 0.676753 	Validation Loss: 0.674206
# Validation loss decreased (0.678543 --> 0.674206).  Saving model ...
# Epoch: 15 	Training Loss: 0.671674 	Validation Loss: 0.668121
# Validation loss decreased (0.674206 --> 0.668121).  Saving model ...
# Epoch: 16 	Training Loss: 0.664629 	Validation Loss: 0.659754
# Validation loss decreased (0.668121 --> 0.659754).  Saving model ...
# Epoch: 17 	Training Loss: 0.655412 	Validation Loss: 0.648395
# Validation loss decreased (0.659754 --> 0.648395).  Saving model ...
# Epoch: 18 	Training Loss: 0.643312 	Validation Loss: 0.632557
# Validation loss decreased (0.648395 --> 0.632557).  Saving model ...
# Epoch: 19 	Training Loss: 0.624623 	Validation Loss: 0.610683
# Validation loss decreased (0.632557 --> 0.610683).  Saving model ...
# Epoch: 20 	Training Loss: 0.601262 	Validation Loss: 0.581198
# Validation loss decreased (0.610683 --> 0.581198).  Saving model ...
# Epoch: 21 	Training Loss: 0.571035 	Validation Loss: 0.544026
# Validation loss decreased (0.581198 --> 0.544026).  Saving model ...
# Epoch: 22 	Training Loss: 0.527581 	Validation Loss: 0.496775
# Validation loss decreased (0.544026 --> 0.496775).  Saving model ...
# Epoch: 23 	Training Loss: 0.483330 	Validation Loss: 0.445013
# Validation loss decreased (0.496775 --> 0.445013).  Saving model ...
# Epoch: 24 	Training Loss: 0.440951 	Validation Loss: 0.393743
# Validation loss decreased (0.445013 --> 0.393743).  Saving model ...
# Epoch: 25 	Training Loss: 0.395191 	Validation Loss: 0.344292
# Validation loss decreased (0.393743 --> 0.344292).  Saving model ...
# Epoch: 26 	Training Loss: 0.354428 	Validation Loss: 0.300450
# Validation loss decreased (0.344292 --> 0.300450).  Saving model ...
# Epoch: 27 	Training Loss: 0.314083 	Validation Loss: 0.263714
# Validation loss decreased (0.300450 --> 0.263714).  Saving model ...
# Epoch: 28 	Training Loss: 0.290182 	Validation Loss: 0.234178
# Validation loss decreased (0.263714 --> 0.234178).  Saving model ...
# Epoch: 29 	Training Loss: 0.263695 	Validation Loss: 0.211734
# Validation loss decreased (0.234178 --> 0.211734).  Saving model ...
# Epoch: 30 	Training Loss: 0.249978 	Validation Loss: 0.193043
# Validation loss decreased (0.211734 --> 0.193043).  Saving model ...
# Epoch: 31 	Training Loss: 0.240218 	Validation Loss: 0.180185
# Validation loss decreased (0.193043 --> 0.180185).  Saving model ...
# Epoch: 32 	Training Loss: 0.224752 	Validation Loss: 0.168908
# Validation loss decreased (0.180185 --> 0.168908).  Saving model ...
# Epoch: 33 	Training Loss: 0.216318 	Validation Loss: 0.160010
# Validation loss decreased (0.168908 --> 0.160010).  Saving model ...
# Epoch: 34 	Training Loss: 0.214231 	Validation Loss: 0.153030
# Validation loss decreased (0.160010 --> 0.153030).  Saving model ...
# Epoch: 35 	Training Loss: 0.200481 	Validation Loss: 0.146931
# Validation loss decreased (0.153030 --> 0.146931).  Saving model ...
# Epoch: 36 	Training Loss: 0.194848 	Validation Loss: 0.141255
# Validation loss decreased (0.146931 --> 0.141255).  Saving model ...
# Epoch: 37 	Training Loss: 0.191840 	Validation Loss: 0.136712
# Validation loss decreased (0.141255 --> 0.136712).  Saving model ...
# Epoch: 38 	Training Loss: 0.187694 	Validation Loss: 0.133361
# Validation loss decreased (0.136712 --> 0.133361).  Saving model ...
# Epoch: 39 	Training Loss: 0.181641 	Validation Loss: 0.129434
# Validation loss decreased (0.133361 --> 0.129434).  Saving model ...
# Epoch: 40 	Training Loss: 0.175359 	Validation Loss: 0.126465
# Validation loss decreased (0.129434 --> 0.126465).  Saving model ...
# Epoch: 41 	Training Loss: 0.173394 	Validation Loss: 0.124000
# Validation loss decreased (0.126465 --> 0.124000).  Saving model ...
# Epoch: 42 	Training Loss: 0.169282 	Validation Loss: 0.122221
# Validation loss decreased (0.124000 --> 0.122221).  Saving model ...
# Epoch: 43 	Training Loss: 0.171871 	Validation Loss: 0.120717
# Validation loss decreased (0.122221 --> 0.120717).  Saving model ...
# Epoch: 44 	Training Loss: 0.168965 	Validation Loss: 0.118391
# Validation loss decreased (0.120717 --> 0.118391).  Saving model ...
# Epoch: 45 	Training Loss: 0.168894 	Validation Loss: 0.118205
# Epoch: 33 	Training Loss: 0.029733 	Validation Loss: 0.118495
# Epoch: 34 	Training Loss: 0.030695 	Validation Loss: 0.117000
# Epoch: 35 	Training Loss: 0.029179 	Validation Loss: 0.117344
# Epoch: 36 	Training Loss: 0.028620 	Validation Loss: 0.120049
# Epoch: 37 	Training Loss: 0.030019 	Validation Loss: 0.117423
# Epoch: 38 	Training Loss: 0.029540 	Validation Loss: 0.117155
# Epoch: 39 	Training Loss: 0.029589 	Validation Loss: 0.119024
# Epoch: 40 	Training Loss: 0.028318 	Validation Loss: 0.116975
# Epoch: 41 	Training Loss: 0.028903 	Validation Loss: 0.119298
# Epoch: 42 	Training Loss: 0.029552 	Validation Loss: 0.117234
# Epoch: 43 	Training Loss: 0.028694 	Validation Loss: 0.121398
# Epoch: 44 	Training Loss: 0.027565 	Validation Loss: 0.117226
# Epoch: 45 	Training Loss: 0.027512 	Validation Loss: 0.118957
# 23531 23531 3222
# 23531 23531 3222

# %%
#Function to test the model
def predict(model, dataloader):
    prediction_list = []
    truth_list = []
    m = 0
    cnt = 0
    for i, batch in enumerate(dataloader):
        outputs = model(batch[0])
        if(outputs[0] < 0.5):
          predicted = 0
        else:
          predicted = 1
        #print(batch[1], predicted)
        if(int(batch[1].item()) == int(predicted)):
          m+=1
        cnt+=1
        #_, predicted = torch.max(outputs.data, 1)
        prediction_list.append(int(predicted))
        truth_list.append(int(batch[1].item()))
    #acc = m/cnt
    return prediction_list, truth_list

# %%
from sklearn.metrics import classification_report

#Loading the model and generating the predictions
model_te.load_state_dict(torch.load('model_te.pt'))
pred, true_val = predict(model_te, test_loader)

print(classification_report(true_val, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       779
#            1       0.97      0.95      0.96       768
#
#     accuracy                           0.96      1547
#    macro avg       0.96      0.96      0.96      1547
# weighted avg       0.96      0.96      0.96      1547

# %% [markdown]
# # RNN

# %%
fans_rnn = []
unlabeled_rnn = []
for X in df['clean_text']:
    ten = []
    for i in range(30):
        res = []
        l = len(X)
        #print(l)
        try:
            if(X[i] in google_w2v):
                res.append(google_w2v[X[i]])
            else:
                res.append(np.zeros(300,dtype = np.float64))
        except:
            res.append(np.zeros(300,dtype = np.float64))
        ten.append(res[0])    
        #print(len(res))
        #print(len(ten))
    #print()
    fans_rnn.append(ten)

for X in df_test['clean_text']:
    ten = []
    for i in range(30):
        res = []
        l = len(X)
        #print(l)
        try:
            if(X[i] in google_w2v):
                res.append(google_w2v[X[i]])
            else:
                res.append(np.zeros(300,dtype = np.float64))
        except:
            res.append(np.zeros(300,dtype = np.float64))
        ten.append(res[0])    
        #print(len(res))
        #print(len(ten))
    #print()
    unlabeled_rnn.append(ten)

# %%
len(fans_rnn[0])
# Out:
# 30

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test  = train_test_split(
        fans_rnn, 
        df['is_depression'],
        train_size=0.80, 
        random_state=1234)

X_train2, X_val, y_train2, y_val = train_test_split(
        X_train, 
        y_train,
        train_size=0.80, 
        random_state=1234)

# %%
class CustomDataset:
    def __init__(self, data, targets):
        self.data = data
        self.targets = targets
    def __len__(self):
        return len(self.data)
    def __getitem__(self, idx):
        current_sample = self.data[idx]
        current_target = self.targets[idx]
        return torch.tensor(current_sample, dtype = torch.float), torch.tensor(current_target, dtype = torch.long)

# %%
train_dataset = CustomDataset(data = X_train2, targets = y_train2.values)
val_dataset = CustomDataset(data = X_val, targets = y_val.values)
test_dataset = CustomDataset(data = X_test, targets = y_test.values)
unlabeled_set = Dataset(X_unlabeled1, np.zeros(len(X_unlabeled1)))

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64,
    num_workers=0)
valid_loader = torch.utils.data.DataLoader(val_dataset,  batch_size=64, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_dataset)

# %%
for X, Y in train_loader:
    print(X.shape, Y.shape)
    break
# Out:
# torch.Size([64, 30, 300]) torch.Size([64])

# %%
import torch.nn as nn
class RNN(nn.Module):
    def __init__(self):
        super(RNN, self).__init__()
        #self.embedding_layer = nn.Embedding(num_embeddings=len(vocab), embedding_dim=embed_len)
        self.rnn = nn.RNN(input_size=300, hidden_size=30, num_layers=1, batch_first=True, nonlinearity='relu')
        self.fc2 = nn.Linear(30, 128)
        self.fc3 = nn.Linear(128, 16)
        self.linear = nn.Linear(16, 2)
        self.dropout = nn.Dropout(0.2)

    def forward(self, X_batch):
        #embeddings = self.embedding_layer(X_batch)
        bs = X_batch.size(0)
        hidden = self.initHidden(bs)
        output, hidden = self.rnn(X_batch,hidden)
        x = F.relu(self.fc2(output[:,-1]))
        x = self.dropout(x)
        x = F.relu(self.fc3(x))
        #x = self.dropout(x)
        x = (self.linear(x))
        return x

    def initHidden(self,bs):
        return torch.zeros(1,bs, 30)
    
n_hidden = 30
rnn = RNN()
print(rnn)
# Out:
# RNN(
#   (rnn): RNN(300, 30, batch_first=True)
#   (fc2): Linear(in_features=30, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=16, bias=True)
#   (linear): Linear(in_features=16, out_features=2, bias=True)
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(rnn.parameters(), lr=0.05)

# %%
valid_loss_min = np.Inf

for epoch in range(50):
    train_loss = 0.0
    #hidden = rnn.initHidden()
    rnn.train()
    for data, target in train_loader:
        #print(len(data[0]))
        optimizer.zero_grad()
        output = rnn(data)
        #print(output)
        #rint(target)

        #target = target.unsqueeze(1)
        #target = target.float()
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*data.size(0)
    rnn.eval()
    for data, target in valid_loader:
          output = rnn(data)
          #target = target.unsqueeze(1)
          #target = target.float()
          loss = criterion(output, target)
          valid_loss += loss.item()*data.size(0)
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
      
    #train_loss = train_loss/len(train_loader.dataset)
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
          epoch+1, 
          train_loss,
          valid_loss
          ))
    if valid_loss <= valid_loss_min:
          print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
          valid_loss_min,
          valid_loss))
          torch.save(rnn.state_dict(), 'rnn.pt')
          valid_loss_min = valid_loss
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-135-c59794f72c58> in <cell line: 3>()
#       8         #print(len(data[0]))
#       9         optimizer.zero_grad()
# ---> 10         output = rnn(data)
#      11         #print(output)
#      12         #rint(target)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-133-1c42bb9a2b00> in forward(self, X_batch)
#      14         bs = X_batch.size(0)
#      15         hidden = self.initHidden(bs)
# ---> 16         output, hidden = self.rnn(X_batch,hidden)
#      17         x = F.relu(self.fc2(output[:,-1]))
#      18         x = self.dropout(x)
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     503
#     504         assert hx is not None
# --> 505         self.check_forward_args(input, hx, batch_sizes)
#     506         assert self.mode == 'RNN_TANH' or self.mode == 'RNN_RELU'
#     507         if batch_sizes is None:
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/rnn.py in check_forward_args(self, input, hidden, batch_sizes)
#     254         expected_hidden_size = self.get_expected_hidden_size(input, batch_sizes)
#     255
# --> 256         self.check_hidden_size(hidden, expected_hidden_size)
#     257
#     258     def permute_hidden(self, hx: Tensor, permutation: Optional[Tensor]):
#
# /usr/local/lib/python3.9/dist-packages/torch/nn/modules/rnn.py in check_hidden_size(self, hx, expected_hidden_size, msg)
#     237                           msg: str = 'Expected hidden size {}, got {}') -> None:
#     238         if hx.size() != expected_hidden_size:
# --> 239             raise RuntimeError(msg.format(expected_hidden_size, list(hx.size())))
#     240
#     241     def _weights_have_changed(self):
#
# RuntimeError: Expected hidden size (1, 1, 30), got [64, 1, 30]

# %%
# Out:
# Accuarcy for RNN is = 0.48933419521654814

# %% [markdown]
# # GRU

# %%
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=64,
    num_workers=0)
valid_loader = torch.utils.data.DataLoader(val_dataset,  batch_size=64, num_workers=0)
test_loader = torch.utils.data.DataLoader(test_dataset)

# %%
class GRU(nn.Module):
    def __init__(self):
        super(GRU, self).__init__()
        #self.embedding_layer = nn.Embedding(num_embeddings=len(vocab), embedding_dim=embed_len)
        self.gru = nn.GRU(input_size=300, hidden_size=30, num_layers=1, batch_first=True)
        self.linear = nn.Linear(30, 3)
        self.relu = nn.ReLU()

    def forward(self, X_batch):
        #embeddings = self.embedding_layer(X_batch)
        bs = X_batch.size(0)
        hidden = self.initHidden(bs)
        output, hidden = self.gru(X_batch, hidden)
        return self.linear(self.relu(output[:,-1]))

    def initHidden(self,bs):
        return torch.zeros(1,bs, 30)
    
n_hidden = 30
gru = GRU()
print(gru)
# Out:
# GRU(
#   (gru): GRU(300, 30, batch_first=True)
#   (linear): Linear(in_features=30, out_features=3, bias=True)
#   (relu): ReLU()
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(gru.parameters(), lr=0.001)

# %%
for epoch in range(50):
    train_loss = 0.0
    #hidden = gru.initHidden(256)
    gru.train()
    for data, target in train_loader:
        #print(len(data[0]))
        optimizer.zero_grad()
        output = gru(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()*data.size(0)
    rnn.eval()
    for data, target in valid_loader:
          output = gru(data)
          #target = target.unsqueeze(1)
          #target = target.float()
          loss = criterion(output, target)
          valid_loss += loss.item()*data.size(0)
    #train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)
    train_loss = train_loss/len(train_loader.dataset)
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
          epoch+1, 
          train_loss,
          valid_loss
          ))
    if valid_loss <= valid_loss_min:
          print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
          valid_loss_min,
          valid_loss))
          torch.save(gru.state_dict(), 'gru.pt')
          valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 0.881888 	Validation Loss: 1.059346
# Validation loss decreased (inf --> 1.059346).  Saving model ...
# Epoch: 2 	Training Loss: 0.715267 	Validation Loss: 0.704522
# Validation loss decreased (1.059346 --> 0.704522).  Saving model ...
# Epoch: 3 	Training Loss: 0.694491 	Validation Loss: 0.691651
# Validation loss decreased (0.704522 --> 0.691651).  Saving model ...
# Epoch: 4 	Training Loss: 0.684684 	Validation Loss: 0.685169
# Validation loss decreased (0.691651 --> 0.685169).  Saving model ...
# Epoch: 5 	Training Loss: 0.679549 	Validation Loss: 0.681718
# Validation loss decreased (0.685169 --> 0.681718).  Saving model ...
# Epoch: 6 	Training Loss: 0.676225 	Validation Loss: 0.678949
# Validation loss decreased (0.681718 --> 0.678949).  Saving model ...
# Epoch: 7 	Training Loss: 0.672923 	Validation Loss: 0.675566
# Validation loss decreased (0.678949 --> 0.675566).  Saving model ...
# Epoch: 8 	Training Loss: 0.665979 	Validation Loss: 0.663653
# Validation loss decreased (0.675566 --> 0.663653).  Saving model ...
# Epoch: 9 	Training Loss: 0.646001 	Validation Loss: 0.640760
# Validation loss decreased (0.663653 --> 0.640760).  Saving model ...
# Epoch: 10 	Training Loss: 0.618317 	Validation Loss: 0.615098
# Validation loss decreased (0.640760 --> 0.615098).  Saving model ...
# Epoch: 11 	Training Loss: 0.595267 	Validation Loss: 0.597494
# Validation loss decreased (0.615098 --> 0.597494).  Saving model ...
# Epoch: 12 	Training Loss: 0.579597 	Validation Loss: 0.587644
# Validation loss decreased (0.597494 --> 0.587644).  Saving model ...
# Epoch: 13 	Training Loss: 0.568072 	Validation Loss: 0.582432
# Validation loss decreased (0.587644 --> 0.582432).  Saving model ...
# Epoch: 14 	Training Loss: 0.559244 	Validation Loss: 0.578992
# Validation loss decreased (0.582432 --> 0.578992).  Saving model ...
# Epoch: 15 	Training Loss: 0.551358 	Validation Loss: 0.576765
# Validation loss decreased (0.578992 --> 0.576765).  Saving model ...
# Epoch: 16 	Training Loss: 0.543943 	Validation Loss: 0.573522
# Validation loss decreased (0.576765 --> 0.573522).  Saving model ...
# Epoch: 17 	Training Loss: 0.536202 	Validation Loss: 0.568279
# Validation loss decreased (0.573522 --> 0.568279).  Saving model ...
# Epoch: 18 	Training Loss: 0.527988 	Validation Loss: 0.562427
# Validation loss decreased (0.568279 --> 0.562427).  Saving model ...
# Epoch: 19 	Training Loss: 0.517202 	Validation Loss: 0.555691
# Validation loss decreased (0.562427 --> 0.555691).  Saving model ...
# Epoch: 20 	Training Loss: 0.506665 	Validation Loss: 0.554667
# Validation loss decreased (0.555691 --> 0.554667).  Saving model ...
# Epoch: 21 	Training Loss: 0.497810 	Validation Loss: 0.554960
# Epoch: 22 	Training Loss: 0.489626 	Validation Loss: 0.555239
# Epoch: 23 	Training Loss: 0.482335 	Validation Loss: 0.554609
# Validation loss decreased (0.554667 --> 0.554609).  Saving model ...
# Epoch: 24 	Training Loss: 0.475691 	Validation Loss: 0.555835
# Epoch: 25 	Training Loss: 0.470426 	Validation Loss: 0.553537
# Validation loss decreased (0.554609 --> 0.553537).  Saving model ...
# Epoch: 26 	Training Loss: 0.465100 	Validation Loss: 0.556979
# Epoch: 27 	Training Loss: 0.460400 	Validation Loss: 0.554208
# Epoch: 28 	Training Loss: 0.455294 	Validation Loss: 0.555629
# Epoch: 29 	Training Loss: 0.451304 	Validation Loss: 0.550158
# Validation loss decreased (0.553537 --> 0.550158).  Saving model ...
# Epoch: 30 	Training Loss: 0.446433 	Validation Loss: 0.546546
# Validation loss decreased (0.550158 --> 0.546546).  Saving model ...
# Epoch: 31 	Training Loss: 0.441464 	Validation Loss: 0.543797
# Validation loss decreased (0.546546 --> 0.543797).  Saving model ...
# Epoch: 32 	Training Loss: 0.436074 	Validation Loss: 0.542482
# Validation loss decreased (0.543797 --> 0.542482).  Saving model ...
# Epoch: 33 	Training Loss: 0.431073 	Validation Loss: 0.538380
# Validation loss decreased (0.542482 --> 0.538380).  Saving model ...
# Epoch: 34 	Training Loss: 0.425386 	Validation Loss: 0.538845
# Epoch: 35 	Training Loss: 0.420381 	Validation Loss: 0.536666
# Epoch: 77 	Training Loss: 0.290589 	Validation Loss: 0.583862
# Epoch: 78 	Training Loss: 0.295573 	Validation Loss: 0.580649
# Epoch: 79 	Training Loss: 0.286508 	Validation Loss: 0.590176
# Epoch: 80 	Training Loss: 0.284720 	Validation Loss: 0.607986
# Epoch: 81 	Training Loss: 0.279825 	Validation Loss: 0.628288
# Epoch: 82 	Training Loss: 0.273658 	Validation Loss: 0.630788
# Epoch: 83 	Training Loss: 0.281207 	Validation Loss: 0.639013
# Epoch: 84 	Training Loss: 0.282430 	Validation Loss: 0.638400
# Epoch: 85 	Training Loss: 0.283943 	Validation Loss: 0.653847
# Epoch: 86 	Training Loss: 0.274811 	Validation Loss: 0.631852
# Epoch: 87 	Training Loss: 0.277172 	Validation Loss: 0.648615
# Epoch: 88 	Training Loss: 0.276120 	Validation Loss: 0.633961
# Epoch: 89 	Training Loss: 0.270235 	Validation Loss: 0.640065
# Epoch: 90 	Training Loss: 0.268011 	Validation Loss: 0.620067
# Epoch: 91 	Training Loss: 0.263463 	Validation Loss: 0.615573
# Epoch: 92 	Training Loss: 0.262982 	Validation Loss: 0.612751
# Epoch: 93 	Training Loss: 0.263062 	Validation Loss: 0.600380
# Epoch: 94 	Training Loss: 0.259621 	Validation Loss: 0.609538
# Epoch: 95 	Training Loss: 0.259889 	Validation Loss: 0.602791
# Epoch: 96 	Training Loss: 0.259115 	Validation Loss: 0.607381
# Epoch: 97 	Training Loss: 0.262263 	Validation Loss: 0.605817
# Epoch: 98 	Training Loss: 0.263133 	Validation Loss: 0.610383
# Epoch: 99 	Training Loss: 0.266089 	Validation Loss: 0.602634
# Epoch: 100 	Training Loss: 0.264696 	Validation Loss: 0.607302

# %%
num_correct = 0
total = 0
for data, labels in test_loader:
            predictions = gru(data)
            #print(predictions)
            #print(torch.argmax(predictions)==labels)
            for i in range(len(predictions)):
                #print(torch.argmax(predictions[i]))
                #print(labels[i])
                if(torch.argmax(predictions[i]) == labels[i]):
                    num_correct += 1

            #print(torch.argmax(predictions[0]))
            #print(labels[0])
            #num_correct += (torch.argmax(predictions)==labels).sum()
            total += labels.size(0)

print('Accuarcy for GRU is =',num_correct/total)
# Out:
# Accuarcy for GRU is = 0.7588881706528765

# %%
gru.load_state_dict(torch.load('gru.pt'))
num_correct = 0
total = 0
for data, labels in test_loader:
            predictions = gru(data)
            #print(predictions)
            #print(torch.argmax(predictions)==labels)
            for i in range(len(predictions)):
                #print(torch.argmax(predictions[i]))
                #print(labels[i])
                if(torch.argmax(predictions[i]) == labels[i]):
                    num_correct += 1

            #print(torch.argmax(predictions[0]))
            #print(labels[0])
            #num_correct += (torch.argmax(predictions)==labels).sum()
            total += labels.size(0)

print('Accuarcy for GRU is =',num_correct/total)
# Out:
# Accuarcy for GRU is = 0.7595345830639948

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')

#Our sentences we like to encode
sentences = ['This framework generates embeddings for each input sentence',
    'Sentences are passed as a list of string.',
    'The quick brown fox jumps over the lazy dog.']

#Sentences are encoded by calling model.encode()
embeddings = model.encode(sentences)

#Print the embeddings
for sentence, embedding in zip(sentences, embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
    print("")
